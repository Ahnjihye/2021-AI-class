# %% [markdown]
# <a href="https://colab.research.google.com/github/Ahnjihye/2021-AI-class/blob/main/2021_1_(%EC%99%84%EC%84%B1%EB%B3%B8)_%EB%8D%B0%EC%9D%B4%ED%84%B0%EB%B6%84%EC%84%9D(%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%EA%B3%BC_%EB%AF%B8%EB%9E%98%EC%82%AC%ED%9A%8C).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. 데이터 업로드하기
#
#
# ```
# from google.colab import files
# uploaded = files.upload()
# ```

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-8c0744af-d2b4-4780-ba55-1a7e0f334edc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8c0744af-d2b4-4780-ba55-1a7e0f334edc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving temperature.csv to temperature.csv

# %% [markdown]
# ## pandas를 활용하여 데이터를 가공할 수 있는 형태로 변경하기

# %% [markdown]
# ```
# import pandas as pd
#
# data = pd.read_csv('파일 이름', encoding='cp949')
# ```

# %%
import pandas as pd

data = pd.read_csv('temperature.csv', encoding='cp949')
data
# Out:
#              일자  평균기온  최저기온  최고기온
# 0    2019-01-01  -5.0  -8.2  -0.6
# 1    2019-01-02  -4.9  -8.8   0.2
# 2    2019-01-03  -3.5  -8.4   3.2
# 3    2019-01-04  -1.1  -6.2   4.1
# 4    2019-01-05  -2.8  -5.5   1.1
# ..          ...   ...   ...   ...
# 360  2019-12-27  -1.7  -4.6   2.6
# 361  2019-12-28   1.1  -3.6   6.1
# 362  2019-12-29   3.8   1.1   6.2
# 363  2019-12-30   2.7  -5.7   6.8
# 364  2019-12-31  -7.9 -10.9  -4.5
#
# [365 rows x 4 columns]

# %% [markdown]
# #### 데이터 통계 파악하기

# %%
data.describe()
# Out:
#              평균기온        최저기온        최고기온
# count  365.000000  365.000000  365.000000
# mean    13.598904    9.321096   18.602192
# std     10.184196   10.372670   10.335448
# min     -7.900000  -10.900000   -4.500000
# 25%      4.300000    0.200000    9.300000
# 50%     14.700000    9.500000   20.200000
# 75%     23.000000   18.900000   27.800000
# max     31.600000   27.900000   36.800000

# %%
# 일자만 골라내기
data['일자']
# Out:
# 0      2019-01-01
# 1      2019-01-02
# 2      2019-01-03
# 3      2019-01-04
# 4      2019-01-05
#           ...
# 360    2019-12-27
# 361    2019-12-28
# 362    2019-12-29
# 363    2019-12-30
# 364    2019-12-31
# Name: 일자, Length: 365, dtype: object

# %%
# 평균 기온만 골라내기
data['평균기온']
# Out:
# 0     -5.0
# 1     -4.9
# 2     -3.5
# 3     -1.1
# 4     -2.8
#       ...
# 360   -1.7
# 361    1.1
# 362    3.8
# 363    2.7
# 364   -7.9
# Name: 평균기온, Length: 365, dtype: float64

# %%
# 최저 기온만 골라내기
data['최저기온']
# Out:
# 0      -8.2
# 1      -8.8
# 2      -8.4
# 3      -6.2
# 4      -5.5
#        ...
# 360    -4.6
# 361    -3.6
# 362     1.1
# 363    -5.7
# 364   -10.9
# Name: 최저기온, Length: 365, dtype: float64

# %%
# 최고 기온만 골라내기
data['최고기온']
# Out:
# 0     -0.6
# 1      0.2
# 2      3.2
# 3      4.1
# 4      1.1
#       ...
# 360    2.6
# 361    6.1
# 362    6.2
# 363    6.8
# 364   -4.5
# Name: 최고기온, Length: 365, dtype: float64

# %% [markdown]
# # 2. 데이터 시각화
#
# ```
# import matplotlib.pyplot as plt
#
# # 그래프 명령어 중 택1
# plt.plot(x축, y축)        # 꺾은선 그래프
# plt.bar(x축, y축)         # 막대 그래프
# plt.scatter(x축, y축)     # 산점도, 산포도
# plt.hist(데이터)          # 히스토그램
# plt.pie(데이터)           # 원그래프
# plt.boxplot(데이터)       # 상자수염 그래프
#
# plt.show()
# ```

# %% [markdown]
# ## 2-1. 꺾은선 그래프 plt.plot()

# %%
import matplotlib.pyplot as plt

plt.plot(data['일자'], data['평균기온'])
plt.show()

# %% [markdown]
# #### x축 눈금 조정하기
#
#
# ```
# plt.xticks(['2019-01-01', '2019-03-01', '2019-05-01', '2019-07-01', '2019-09-01', '2019-11-01', '2020-01-01'],
#            ['2019-01', '2019-03', '2019-05', '2019-07', '2019-09', '2019-11', '2020-01'])
# ```

# %%
plt.plot(data['일자'], data['최저기온'])
plt.xticks(['2019-01-01', '2019-03-01', '2019-05-01', '2019-07-01', '2019-09-01', '2019-11-01', '2020-01-01'], 
           ['2019-01', '2019-03', '2019-05', '2019-07', '2019-09', '2019-11', '2020-01'])
plt.show()

# %% [markdown]
# #### 해상도 설정하기
#
#
# ```
# plt.figure(dpi = 해상도)
# ```

# %%
plt.figure(dpi=100)
plt.plot(data['일자'], data['최저기온'])
plt.xticks(['2019-01-01', '2019-03-01', '2019-05-01', '2019-07-01', '2019-09-01', '2019-11-01', '2020-01-01'], 
           ['2019-01', '2019-03', '2019-05', '2019-07', '2019-09', '2019-11', '2020-01'])
plt.show()

# %% [markdown]
# #### 그래프 색상 설정하기
#
#
# ```
# plt.plot(x축, y축, color = '색상명')
# ```

# %%
plt.figure(dpi=100)
plt.plot(data['일자'], data['최저기온'], color='black')
plt.xticks(['2019-01-01', '2019-03-01', '2019-05-01', '2019-07-01', '2019-09-01', '2019-11-01', '2020-01-01'], 
           ['2019-01', '2019-03', '2019-05', '2019-07', '2019-09', '2019-11', '2020-01'])
plt.show()

# %% [markdown]
# #### 범례 설정하기
#
#
# ```
# plt.plot(x축, y축, label = '표시할 범례')
# plt.legend()
# ```

# %%
plt.figure(dpi=100)
plt.plot(data['일자'], data['최저기온'], color='black', label='avg')
plt.xticks(['2019-01-01', '2019-03-01', '2019-05-01', '2019-07-01', '2019-09-01', '2019-11-01', '2020-01-01'], 
           ['2019-01', '2019-03', '2019-05', '2019-07', '2019-09', '2019-11', '2020-01'])
plt.legend()
plt.show()

# %% [markdown]
# #### 꺾은선 그래프 여러 개 겹쳐 그리기

# %%
plt.figure(dpi=100)
plt.plot(data['일자'], data['평균기온'], color ='black', label='avg')
plt.plot(data['일자'], data['최저기온'], color ='blue', label='min')
plt.xticks(['2019-01-01', '2019-03-01', '2019-05-01', '2019-07-01', '2019-09-01', '2019-11-01', '2020-01-01'], 
           ['2019-01', '2019-03', '2019-05', '2019-07', '2019-09', '2019-11', '2020-01'])
plt.legend()
plt.show()

# %%
plt.figure(dpi=100)
plt.plot(data['일자'], data['평균기온'], color ='black', label='avg')
plt.plot(data['일자'], data['최저기온'], color ='blue', label='min')
plt.plot(data['일자'], data['최고기온'], color ='red', label='max')
plt.xticks(['2019-01-01', '2019-03-01', '2019-05-01', '2019-07-01', '2019-09-01', '2019-11-01', '2020-01-01'], 
           ['2019-01', '2019-03', '2019-05', '2019-07', '2019-09', '2019-11', '2020-01'])
plt.legend()
plt.show()

# %%
plt.figure(dpi=100)
plt.plot(data['일자'], data['최저기온'], color ='blue', label='min')
plt.plot(data['일자'], data['최고기온'], color ='red', label='max')
plt.xticks(['2019-01-01', '2019-03-01', '2019-05-01', '2019-07-01', '2019-09-01', '2019-11-01', '2020-01-01'], 
           ['2019-01', '2019-03', '2019-05', '2019-07', '2019-09', '2019-11', '2020-01'])
plt.legend()
plt.show()

# %% [markdown]
# #### 2019년의 날씨를 분석해보자.
#
# > 내용 작성하기

# %% [markdown]
# ## 2-2. 막대그래프 plt.bar()

# %%
plt.figure(dpi=100)
plt.bar(data['일자'], data['최저기온'], color ='blue', label='min')
plt.xticks(['2019-01-01', '2019-03-01', '2019-05-01', '2019-07-01', '2019-09-01', '2019-11-01', '2020-01-01'], 
           ['2019-01', '2019-03', '2019-05', '2019-07', '2019-09', '2019-11', '2020-01'])
plt.legend()
plt.show()

# %%
plt.figure(dpi=100)
plt.bar(data['일자'], data['최고기온'], color ='red', label='max')
plt.xticks(['2019-01-01', '2019-03-01', '2019-05-01', '2019-07-01', '2019-09-01', '2019-11-01', '2020-01-01'], 
           ['2019-01', '2019-03', '2019-05', '2019-07', '2019-09', '2019-11', '2020-01'])
plt.legend()
plt.show()

# %% [markdown]
# 2019년에서 일교차가 가장 큰 날은?

# %%
plt.figure(dpi=100)
plt.bar(data['일자'], data['최저기온'], color ='blue', label='min')
plt.bar(data['일자'], data['최고기온'], color ='red', label='max')
plt.xticks(['2019-01-01', '2019-03-01', '2019-05-01', '2019-07-01', '2019-09-01', '2019-11-01', '2020-01-01'], 
           ['2019-01', '2019-03', '2019-05', '2019-07', '2019-09', '2019-11', '2020-01'])
plt.legend()
plt.show()

# %% [markdown]
# 왜 그래프가 잘 안나타날까?
# > 내용 작성하기

# %%
plt.figure(dpi=100)
plt.bar(data['일자'], data['최고기온'], color ='red')
plt.bar(data['일자'], data['최저기온'], color ='blue')
plt.xticks(['2019-01-01', '2019-03-01', '2019-05-01', '2019-07-01', '2019-09-01', '2019-11-01', '2020-01-01'], 
           ['2019-01', '2019-03', '2019-05', '2019-07', '2019-09', '2019-11', '2020-01'])
plt.show()

# %% [markdown]
# #### 일교차 데이터 추가하기

# %%
data['일교차'] = data['최고기온']-data['최저기온']

# %%
data
# Out:
#              일자  평균기온  최저기온  최고기온   일교차
# 0    2019-01-01  -5.0  -8.2  -0.6   7.6
# 1    2019-01-02  -4.9  -8.8   0.2   9.0
# 2    2019-01-03  -3.5  -8.4   3.2  11.6
# 3    2019-01-04  -1.1  -6.2   4.1  10.3
# 4    2019-01-05  -2.8  -5.5   1.1   6.6
# ..          ...   ...   ...   ...   ...
# 360  2019-12-27  -1.7  -4.6   2.6   7.2
# 361  2019-12-28   1.1  -3.6   6.1   9.7
# 362  2019-12-29   3.8   1.1   6.2   5.1
# 363  2019-12-30   2.7  -5.7   6.8  12.5
# 364  2019-12-31  -7.9 -10.9  -4.5   6.4
#
# [365 rows x 5 columns]

# %%
data['일교차']
# Out:
# 0       7.6
# 1       9.0
# 2      11.6
# 3      10.3
# 4       6.6
#        ...
# 360     7.2
# 361     9.7
# 362     5.1
# 363    12.5
# 364     6.4
# Name: 일교차, Length: 365, dtype: float64

# %%
plt.figure(dpi=100)
plt.bar(data['일자'], data['일교차'], color ='crimson')
plt.xticks(['2019-01-01', '2019-03-01', '2019-05-01', '2019-07-01', '2019-09-01', '2019-11-01', '2020-01-01'], 
           ['2019-01', '2019-03', '2019-05', '2019-07', '2019-09', '2019-11', '2020-01'])
plt.show()

# %% [markdown]
# ## 2-4. 산점도 plt.scatter()

# %%
plt.figure(dpi=100)
plt.scatter(data['일자'], data['일교차'], color ='crimson')
plt.xticks(['2019-01-01', '2019-03-01', '2019-05-01', '2019-07-01', '2019-09-01', '2019-11-01', '2020-01-01'], 
           ['2019-01', '2019-03', '2019-05', '2019-07', '2019-09', '2019-11', '2020-01'])
plt.show()

# %%
plt.figure(dpi=100)
plt.scatter(data['최저기온'], data['최고기온'], color ='green')
plt.show()

# %% [markdown]
# #### x축, y축 이름 붙이기
#
#
# ```
# plt.xlabel('축이름')
# plt.ylabel('축이름')
# ```

# %%
plt.figure(dpi=100)
plt.scatter(data['최저기온'], data['최고기온'], color ='green')
plt.xlabel('minimum temperature')
plt.ylabel('maximum temperature')
plt.show()
